# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset
# - Our dataset is taken form the worldbank Youth Global Unemployment rate information

# %%
df=pd.read_csv('unemp.csv')
df.head(5)
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %% [markdown]
# ## Problem Statement
# - We need to analyze the youth global unemployment dataset for last five years , from2017 to 2021 to get the answers for the following points and plot the results :
#     1. List all the countries where youth unemployment is greater than or equal to 25% in 2021.
#     2. List all countries where youth unemployment is less than or equal to 1% in2021
#     3. Top 10 countries that have an average high rate of youth unemployment from2017 to 2021
#     4. Top 10 countries that have an average low rate of youth unemployment from2017 to 2021
#     5. Top 10 countries that have a high COVID impact (for years 2019 and 2020)
#     6. Top 10 countries that have a less COVID impact (for years 2019 and 2020)

# %% [markdown]
# ## Step by Step to perform data analysis

# %% [markdown]
# ### 1. Importing The Dataset

# %%
df=pd.read_csv('unemp.csv')

# %% [markdown]
# ### 2. Exploring,Selecting,Cleaning and preparing the data

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
df.shape
# Out:
# (235, 33)

# %%
# Creating a new dataframe with 5 years data
df5=df.iloc[0:,[0,1,28,29,30,31,32]]

# %%
# Check for nulls
df5.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
df5.dropna()
# Out:
#                     Country Name Country Code   2017   2018   2019   2020  \
# 0    Africa Eastern and Southern          AFE   6.71   6.73   6.91   7.56
# 1                    Afghanistan          AFG  11.18  11.15  11.22  11.71
# 2     Africa Western and Central          AFW   6.02   6.04   6.06   6.77
# 3                         Angola          AGO   7.41   7.42   7.42   8.33
# 4                        Albania          ALB  13.62  12.30  11.47  13.33
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   8.58   8.69   8.41   9.15
# 231                  Yemen, Rep.          YEM  13.30  13.15  13.06  13.39
# 232                 South Africa          ZAF  27.04  26.91  28.47  29.22
# 233                       Zambia          ZMB  11.63  12.01  12.52  12.85
# 234                     Zimbabwe          ZWE   4.78   4.80   4.83   5.35
#
#       2021
# 0     8.11
# 1    13.28
# 2     6.84
# 3     8.53
# 4    11.82
# ...

# %%
# checking for duplicated
df5.duplicated().sum()
# Out:
# 0

# %%
df5.dtypes
# Out:
# Country Name     object
# Country Code     object
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
# sorting the DataFrame
df5.sort_values('Country Name')
# Out:
#                     Country Name Country Code   2017   2018   2019   2020  \
# 1                    Afghanistan          AFG  11.18  11.15  11.22  11.71
# 0    Africa Eastern and Southern          AFE   6.71   6.73   6.91   7.56
# 2     Africa Western and Central          AFW   6.02   6.04   6.06   6.77
# 4                        Albania          ALB  13.62  12.30  11.47  13.33
# 52                       Algeria          DZA  10.33  10.42  10.51  12.55
# ..                           ...          ...    ...    ...    ...    ...
# 172           West Bank and Gaza          PSE  25.68  26.26  25.34  25.89
# 229                        World          WLD   5.56   5.39   5.36   6.57
# 231                  Yemen, Rep.          YEM  13.30  13.15  13.06  13.39
# 233                       Zambia          ZMB  11.63  12.01  12.52  12.85
# 234                     Zimbabwe          ZWE   4.78   4.80   4.83   5.35
#
#       2021
# 1    13.28
# 0     8.11
# 2     6.84
# 4    11.82
# 52   12.70
# ...

# %%
# setting the index(setting COUNTRY CODE column as an index of the following coding snippet)
df5.set_index('Country Code',inplace=True)

# %%
df5
# Out:
#                              Country Name   2017   2018   2019   2020   2021
# Country Code
# AFE           Africa Eastern and Southern   6.71   6.73   6.91   7.56   8.11
# AFG                           Afghanistan  11.18  11.15  11.22  11.71  13.28
# AFW            Africa Western and Central   6.02   6.04   6.06   6.77   6.84
# AGO                                Angola   7.41   7.42   7.42   8.33   8.53
# ALB                               Albania  13.62  12.30  11.47  13.33  11.82
# ...                                   ...    ...    ...    ...    ...    ...
# WSM                                 Samoa   8.58   8.69   8.41   9.15   9.84
# YEM                           Yemen, Rep.  13.30  13.15  13.06  13.39  13.57
# ZAF                          South Africa  27.04  26.91  28.47  29.22  33.56
# ZMB                                Zambia  11.63  12.01  12.52  12.85  13.03
# ZWE                              Zimbabwe   4.78   4.80   4.83   5.35   5.17
#
# [235 rows x 6 columns]

# %%
# Adding two new columns 5yrsavg and covid year difference
df5['5yrsavg']=df5[['2017','2018','2019','2020','2021']].mean(axis=1)
df5['covid_yr_diff']=df5['2020']-df5['2019']

# %%
df5
# Out:
#                              Country Name   2017   2018   2019   2020   2021  \
# Country Code
# AFE           Africa Eastern and Southern   6.71   6.73   6.91   7.56   8.11
# AFG                           Afghanistan  11.18  11.15  11.22  11.71  13.28
# AFW            Africa Western and Central   6.02   6.04   6.06   6.77   6.84
# AGO                                Angola   7.41   7.42   7.42   8.33   8.53
# ALB                               Albania  13.62  12.30  11.47  13.33  11.82
# ...                                   ...    ...    ...    ...    ...    ...
# WSM                                 Samoa   8.58   8.69   8.41   9.15   9.84
# YEM                           Yemen, Rep.  13.30  13.15  13.06  13.39  13.57
# ZAF                          South Africa  27.04  26.91  28.47  29.22  33.56
# ZMB                                Zambia  11.63  12.01  12.52  12.85  13.03
# ZWE                              Zimbabwe   4.78   4.80   4.83   5.35   5.17
#
# ...

# %% [markdown]
# ## plotting

# %%
# plotting the 5 year average unemployment data

# %%
avg5yrs=df5['5yrsavg']# x values
countries=df5.index
plt.figure(figsize=(12,6))
plt.bar(countries,avg5yrs)
plt.xlabel('Countries')
plt.ylabel('5-Year Average')
plt.title('5-Year Average by Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1. Performing the data analysis and plotting the summary of them

# %% [markdown]
# ###### i.List all countries where youth unemployment is greater than or equal to25% in 2021.

# %%
#List all countries where youth unemployment is greater than or equal to 25% in 2021.
df5[df5['2021']>25][['Country Name','2021']]
# Out:
#               Country Name   2021
# Country Code
# DJI               Djibouti  28.39
# SWZ               Eswatini  25.76
# ZAF           South Africa  33.56

# %% [markdown]
# ###### ii. List all countries where youth unemployment is less than or equal to 1% in2021.

# %%
#List all countries where youth unemployment is less than or equal to 1% in2021.
df5[df5['2021']<=1][['Country Name','2021']]
# Out:
#              Country Name  2021
# Country Code
# KHM              Cambodia  0.61
# NER                 Niger  0.75
# QAT                 Qatar  0.26

# %% [markdown]
# ###### iii. Top 10 countries that have an average high rate of youth unemployment from 2017 to 2021.

# %%
top10cont=df5.sort_values('5yrsavg',ascending=False)[0:10]

# %%
top10cont
# Out:
#                                 Country Name   2017   2018   2019   2020  \
# Country Code
# ZAF                             South Africa  27.04  26.91  28.47  29.22
# DJI                                 Djibouti  26.06  26.19  26.36  28.39
# PSE                       West Bank and Gaza  25.68  26.26  25.34  25.89
# SWZ                                 Eswatini  22.75  22.79  22.84  25.51
# LSO                                  Lesotho  23.20  22.81  22.44  24.56
# BWA                                 Botswana  21.57  22.07  22.61  24.93
# COG                              Congo, Rep.  20.56  20.61  20.62  22.84
# GAB                                    Gabon  20.72  20.75  20.74  21.97
# NAM                                  Namibia  21.64  19.88  19.99  21.45
# VCT           St. Vincent and the Grenadines  19.18  19.18  19.28  21.00
#
#                2021  5yrsavg  covid_yr_diff
# Country Code
# ZAF           33.56   29.040           0.75
# DJI           28.39   27.078           2.03
# ...

# %%
# plot of the top 10 countries with highest unemployment rate

# %%
uemp=top10cont['5yrsavg']

# %%
countries=top10cont.index

# %%
plt.bar(countries,uemp)
plt.xlabel('countrycode',fontsize=12)
plt.ylabel("5 Yrs Avg Unemployment Rate",fontsize=14)
plt.xticks(rotation="vertical",fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ######  iv.Top 10 countries that have an average low rate of youth unemployment from 2017 to 2021

# %%
top10cont_lowunemp=df5.sort_values('5yrsavg')[0:10]
# Out:
# Country Code
# QAT    0.164
# KHM    0.274
# NER    0.602
# SLB    0.826
# LAO    0.956
# THA    0.968
# MMR    1.232
# RWA    1.290
# TCD    1.398
# BHR    1.446
# Name: 5yrsavg, dtype: float64

# %%
# plotting
lowunemp=top10cont_lowunemp['5yrsavg']
countries=top10cont_lowunemp.index
plt.bar(countries,lowunemp)
plt.xlabel('countrycode',fontsize=12)
plt.ylabel('Top 10 countries with low unemployment rate',fontsize=12)
plt.show()

# %% [markdown]
# ##### v. Top 10 countries that have a high covid impact on the unemployment rate (for the immediate year 2019 and covid year 2020)

# %%
df5
# Out:
#                              Country Name   2017   2018   2019   2020   2021  \
# Country Code
# AFE           Africa Eastern and Southern   6.71   6.73   6.91   7.56   8.11
# AFG                           Afghanistan  11.18  11.15  11.22  11.71  13.28
# AFW            Africa Western and Central   6.02   6.04   6.06   6.77   6.84
# AGO                                Angola   7.41   7.42   7.42   8.33   8.53
# ALB                               Albania  13.62  12.30  11.47  13.33  11.82
# ...                                   ...    ...    ...    ...    ...    ...
# WSM                                 Samoa   8.58   8.69   8.41   9.15   9.84
# YEM                           Yemen, Rep.  13.30  13.15  13.06  13.39  13.57
# ZAF                          South Africa  27.04  26.91  28.47  29.22  33.56
# ZMB                                Zambia  11.63  12.01  12.52  12.85  13.03
# ZWE                              Zimbabwe   4.78   4.80   4.83   5.35   5.17
#
# ...

# %%
highcovidimpact=df5.sort_values('covid_yr_diff',ascending=False)[0:10]
highcovidimpact
# Out:
#                Country Name   2017   2018   2019   2020   2021  5yrsavg  \
# Country Code
# PAN                  Panama   3.86   3.83   4.73  12.85  12.09    7.472
# GEO                 Georgia  13.94  12.67  11.57  18.50  10.66   13.468
# CRI              Costa Rica   8.14   9.63  11.49  17.41  17.95   12.924
# COL                Colombia   8.87   9.11   9.96  15.04  14.34   11.464
# USA           United States   4.36   3.90   3.67   8.05   5.46    5.088
# NAC           North America   4.58   4.11   3.89   8.21   5.70    5.298
# BOL                 Bolivia   3.65   3.52   3.82   7.90   8.51    5.480
# CHL                   Chile   6.96   7.23   7.29  11.18   9.13    8.358
# CAN                  Canada   6.34   5.83   5.66   9.46   7.51    6.960
# PER                    Peru   3.69   3.49   3.38   7.18   4.83    4.514
#
#               covid_yr_diff
# Country Code
# PAN                    8.12
# GEO                    6.93
# CRI                    5.92
# COL                    5.08
# ...

# %%
coviddiffdata=highcovidimpact['covid_yr_diff']

# %%
# plotting
plt.bar(highcovidimpact.index,coviddiffdata)
plt.xlabel('Country Code',fontsize=12)
plt.ylabel("Rate")
plt.grid()
plt.show()

# %% [markdown]
# ###### vi. Top 10 countries that have a less covid impact (for the immediate year 2019 and the covid year 2020)

# %%
lowimpact=df5.sort_values('covid_yr_diff')[0:10]
lowimpact
# Out:
#                         Country Name   2017   2018   2019   2020   2021  \
# Country Code
# SRB                           Serbia  13.48  12.73  10.39   9.01  11.81
# MDA                          Moldova   4.10   4.11   5.10   3.82   3.96
# GRC                           Greece  21.49  19.29  17.31  16.30  14.80
# ITA                            Italy  11.21  10.61   9.95   9.16   9.83
# TUR                          Turkiye  10.82  10.89  13.67  13.11  13.39
# BIH           Bosnia and Herzegovina  20.53  18.40  15.69  15.27  15.22
# FRA                           France   9.41   9.02   8.41   8.01   8.06
# DOM               Dominican Republic   5.83   5.86   6.36   6.13   8.50
# POL                           Poland   4.89   3.85   3.28   3.16   3.37
# MKD                  North Macedonia  22.38  20.74  17.26  17.20  16.20
#
#               5yrsavg  covid_yr_diff
# Country Code
# SRB            11.484          -1.38
# MDA             4.218          -1.28
# ...

# %%
# Plotting
datas=lowimpact['covid_yr_diff']

plt.bar(lowimpact.index,datas)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Conclusion
# - Here wecomplete data analysis which id done step by step . We perform different steps from importing data into the DataFrame ,exploring and understanding the data and cleaning and preparing the data according to the problem so that it can be used to  answer the question by analyzing the data .
# - we have plotted our results which we have got after doing data analysis .
